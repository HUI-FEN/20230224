# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

#命令列:sudo apt-get update -y
#命令列:sudo apt-get install -y fonts-wqy-zenhei

#codespace
font = FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
#windows
#font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)
#============#
#mac
#font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)

student1 = {'國文':78, '英文': 80, '數學':75, '歷史': 85, '探索':92}
student2 = {'國文':90, '英文': 75, '數學':98, '歷史': 65, '探索':75}

subjects=list(student1.keys())
scores1=list(student1.values())
scores2=list(student2.values())

fig=plt.figure(figsize=(8, 5),dpi=250,facecolor='#cccccc')
axes=fig.add_subplot(1,1,1)
axes.plot(subjects,scores1,'r^-.',label='stu1')
axes.plot(subjects,scores2,'go--',label='stu2')
axes.set_xticklabels(subjects,fontproperties=font)
axes.legend()
plt.show()
# Out:
# /tmp/ipykernel_8751/1388154066.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(subjects,fontproperties=font)

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

#命令列:sudo apt-get update -y
#命令列:sudo apt-get install -y fonts-wqy-zenhei

#codespace
font = FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
#windows
#font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)
#============#
#mac
#font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)

student1 = {'國文':78, '英文': 80, '數學':75, '歷史': 85, '探索':92}
student2 = {'國文':90, '英文': 75, '數學':98, '歷史': 65, '探索':75}

subjects=list(student1.keys())
scores1=list(student1.values())
scores2=list(student2.values())

fig=plt.figure(figsize=(8, 5),dpi=250,facecolor='#cccccc')
axes=fig.add_subplot(1,1,1)
axes.plot(subjects,scores1,'r^-.',label='學生1')
axes.plot(subjects,scores2,'go--',label='學生2')
axes.set_xticklabels(subjects,fontproperties=font)
axes.set_title("學生1和學生2分數比較表",fontproperties=font)
axes.set_xlabel("科目",fontproperties=font)
axes.set_ylabel("分數",fontproperties=font)
axes.legend(prop=font)
plt.show()
# Out:
# /tmp/ipykernel_8751/2145716562.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(subjects,fontproperties=font)

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

#命令列:sudo apt-get update -y
#命令列:sudo apt-get install -y fonts-wqy-zenhei

#codespace
font = FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
#windows
#font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)
#============#
#mac
#font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)

student1 = {'國文':78, '英文': 80, '數學':75, '歷史': 85, '探索':92}
student2 = {'國文':90, '英文': 75, '數學':98, '歷史': 65, '探索':75}

subjects=list(student1.keys())
scores1=list(student1.values())
scores2=list(student2.values())

fig=plt.figure(figsize=(8, 5),dpi=250,facecolor='#cccccc')
axes=fig.add_subplot(1,1,1)
axes.plot(subjects,scores1,'r^-.',label='學生1')
axes.plot(subjects,scores2,'go--',label='學生2')
axes.set_xticklabels(subjects,fontproperties=font)
axes.set_title("學生1和學生2分數比較表",fontproperties=font)
axes.set_xlabel("科目",fontproperties=font)
axes.set_ylabel("分數",fontproperties=font)
axes.legend(prop=font)
xtick_nums = axes.get_xticks()
for index in range(len(xtick_nums)):
    print("學生1:")
    print(xtick_nums[index],scores1[index])
    print("學生2:")
    print(xtick_nums[index],scores2[index])
plt.show()
# Out:
# /tmp/ipykernel_8751/3903543450.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(subjects,fontproperties=font)
# 學生1:
# 0 78
# 學生2:
# 0 90
# 學生1:
# 1 80
# 學生2:
# 1 75
# 學生1:
# 2 75
# 學生2:
# 2 98
# 學生1:
# 3 85
# 學生2:
# 3 65
# 學生1:
# 4 92
# 學生2:
# 4 75

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

#命令列:sudo apt-get update -y
#命令列:sudo apt-get install -y fonts-wqy-zenhei

#codespace
font = FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
#windows
#font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)
#============#
#mac
#font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)

student1 = {'國文':78, '英文': 80, '數學':75, '歷史': 85, '探索':92}
student2 = {'國文':90, '英文': 75, '數學':98, '歷史': 65, '探索':75}

subjects=list(student1.keys())
scores1=list(student1.values())
scores2=list(student2.values())

fig=plt.figure(figsize=(8, 5),dpi=250,facecolor='#cccccc')
axes=fig.add_subplot(1,1,1)
axes.plot(subjects,scores1,'r^-.',label='學生1')
axes.plot(subjects,scores2,'go--',label='學生2')
axes.set_xticklabels(subjects,fontproperties=font)
axes.set_title("學生1和學生2分數比較表",fontproperties=font)
axes.set_xlabel("科目",fontproperties=font)
axes.set_ylabel("分數",fontproperties=font)
axes.legend(prop=font)
xtick_nums = axes.get_xticks()
for index in range(len(xtick_nums)):
    axes.annotate(str(scores1[index]),(xtick_nums[index],scores1[index]))
    axes.annotate(str(scores2[index]),(xtick_nums[index],scores2[index]))

plt.show()
# Out:
# /tmp/ipykernel_8751/2150568738.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(subjects,fontproperties=font)

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

#命令列:sudo apt-get update -y
#命令列:sudo apt-get install -y fonts-wqy-zenhei

#codespace
font = FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
#windows
#font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)
#============#
#mac
#font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)

student1 = {'國文':78, '英文': 80, '數學':75, '歷史': 85, '探索':92}
student2 = {'國文':90, '英文': 75, '數學':98, '歷史': 65, '探索':75}

subjects=list(student1.keys())
scores1=list(student1.values())
scores2=list(student2.values())

fig=plt.figure(figsize=(8, 5),dpi=250,facecolor='#cccccc')
axes=fig.add_subplot(1,1,1)
axes.plot(subjects,scores1,'r^-.',label='學生1')
axes.plot(subjects,scores2,'go--',label='學生2')
axes.set_xticklabels(subjects,fontproperties=font)
axes.set_title("學生1和學生2分數比較表",fontproperties=font)
axes.set_xlabel("科目",fontproperties=font)
axes.set_ylabel("分數",fontproperties=font)
axes.legend(prop=font)
xtick_nums = axes.get_xticks()
for index in range(len(xtick_nums)):
    axes.annotate(str(scores1[index]),(xtick_nums[index]+0.5,scores1[index]))
    axes.annotate(str(scores2[index]),(xtick_nums[index],scores2[index]))

plt.show()
# Out:
# /tmp/ipykernel_8751/1688788119.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(subjects,fontproperties=font)

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

#命令列:sudo apt-get update -y
#命令列:sudo apt-get install -y fonts-wqy-zenhei

#codespace
font = FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
#windows
#font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)
#============#
#mac
#font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)

student1 = {'國文':78, '英文': 80, '數學':75, '歷史': 85, '探索':92}
student2 = {'國文':90, '英文': 75, '數學':98, '歷史': 65, '探索':75}

subjects=list(student1.keys())
scores1=list(student1.values())
scores2=list(student2.values())

fig=plt.figure(figsize=(8, 5),dpi=250,facecolor='#cccccc')
axes=fig.add_subplot(1,1,1)
axes.plot(subjects,scores1,'r^-.',label='學生1')
axes.plot(subjects,scores2,'go--',label='學生2')
axes.set_xticklabels(subjects,fontproperties=font)
axes.set_title("學生1和學生2分數比較表",fontproperties=font)
axes.set_xlabel("科目",fontproperties=font)
axes.set_ylabel("分數",fontproperties=font)
axes.legend(prop=font)
xtick_nums = axes.get_xticks()
for index in range(len(xtick_nums)):
    axes.annotate(str(scores1[index]),(xtick_nums[index]+0.1,scores1[index]))
    axes.annotate(str(scores2[index]),(xtick_nums[index],scores2[index]))

axes.grid(axis='y')
plt.show()
# Out:
# /tmp/ipykernel_8751/874756050.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(subjects,fontproperties=font)
