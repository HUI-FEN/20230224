# %%
import pandas as pd
import numpy as np
frame = pd.DataFrame(np.random.randn(4,3),
                    columns=list('bde'),
                    index=['台北','台中','台南','高雄'])

frame
# Out:
#            b         d         e
# 台北 -0.741371 -0.931793 -0.254746
# 台中 -0.316589 -0.022355  1.708842
# 台南  0.702245 -1.246562  0.418932
# 高雄 -0.166047  1.036957 -0.555468

# %%
np.abs(frame)
# Out:
#            b         d         e
# 台北  0.741371  0.931793  0.254746
# 台中  0.316589  0.022355  1.708842
# 台南  0.702245  1.246562  0.418932
# 高雄  0.166047  1.036957  0.555468

# %%
np.sum(frame)
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# b   -0.521761
# d   -1.163753
# e    1.317559
# dtype: float64

# %%
frame
# Out:
#            b         d         e
# 台北 -0.741371 -0.931793 -0.254746
# 台中 -0.316589 -0.022355  1.708842
# 台南  0.702245 -1.246562  0.418932
# 高雄 -0.166047  1.036957 -0.555468

# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50,101,size=(50,5))
scores_df = pd.DataFrame(scores,columns=['國文', '英文', '數學', '地理', '歷史'],index=range(1,51))
scores_df
# Out:
#      國文   英文  數學  地理   歷史
# 1    97   99  79  50  100
# 2    68   79  75  97   98
# 3    69   54  62  68   82
# 4    81   98  78  57   67
# 5    88   53  66  57   52
# 6    62   64  99  84   60
# 7    57   60  71  57   83
# 8    60   52  78  92   95
# 9    53   94  75  50   78
# 10   53   70  83  69   77
# 11   75   60  51  73   72
# 12   64   61  52  61   67
# 13   93   52  68  71   71
# 14   98   83  60  78   64
# 15   53   82  83  88   54
# 16   92   63  72  73   96
# 17   91   65  52  63   78
# 18   72   50  51  97  100
# 19   55   88  74  93   83
# 20   59   75  90  61   84
# 21   57   96  86  69   64
# 22   71   59  93  69   53
# 23   69   84  74  91  100
# 24   59   52  64  99   86
# 25   99   57  97  50   89
# 26   53   97  99  94   93
# 27  100   70  57  69   84
# 28   90   89  54  76   93
# 29   63   57  91  62   79
# 30   69   72  88  92   74
# 31   80   81  95  62   53
# 32   68   82  79  88   70
# 33   80   67  61  90   99
# 34   91   68  76  65   96
# ...

# %%
# dataframe使用統計的方法,sum,mean,max,min,median,count,std
scores_sum = scores_df.sum(axis=1)
#scores_average = scores_sum / 5.0
scores_average = scores_df.mean(axis=1)
scores_average
# Out:
# 1     133.571429
# 2     131.057143
# 3     105.285714
# 4     119.742857
# 5      99.314286
# 6     115.971429
# 7     103.085714
# 8     118.485714
# 9     110.000000
# 10    110.628571
# 11    104.028571
# 12     95.857143
# 13    111.571429
# 14    120.371429
# 15    113.142857
# 16    124.457143
# 17    109.685714
# 18    116.285714
# 19    123.514286
# 20    115.971429
# 21    116.914286
# 22    108.428571
# 23    131.371429
# 24    113.142857
# 25    123.200000
# 26    137.028571
# 27    119.428571
# 28    126.342857
# 29    110.628571
# 30    124.142857
# 31    116.600000
# 32    121.628571
# 33    124.771429
# 34    124.457143
# 35    108.114286
# 36    112.828571
# 37    123.514286
# 38    115.971429
# 39    153.685714
# 40    105.914286
# 41    125.400000
# 42    115.657143
# 43    106.857143
# 44    114.400000
# 45    112.828571
# 46    113.142857
# 47    115.342857
# 48    133.257143
# 49    115.342857
# 50    126.971429
# dtype: float64

# %%
# dataframe使用統計的方法,sum,mean,max,min,median,count,std
scores_sum = scores_df.sum(axis=1)
#scores_average = scores_sum / 5.0
scores_average = scores_df.mean(axis=1)
scores_average
scores_df['總分'] = scores_sum
scores_df['平均'] = scores_average
scores_df
# Out:
#      國文   英文  數學  地理   歷史   總分    平均
# 1    97   99  79  50  100  425  85.0
# 2    68   79  75  97   98  417  83.4
# 3    69   54  62  68   82  335  67.0
# 4    81   98  78  57   67  381  76.2
# 5    88   53  66  57   52  316  63.2
# 6    62   64  99  84   60  369  73.8
# 7    57   60  71  57   83  328  65.6
# 8    60   52  78  92   95  377  75.4
# 9    53   94  75  50   78  350  70.0
# 10   53   70  83  69   77  352  70.4
# 11   75   60  51  73   72  331  66.2
# 12   64   61  52  61   67  305  61.0
# 13   93   52  68  71   71  355  71.0
# 14   98   83  60  78   64  383  76.6
# 15   53   82  83  88   54  360  72.0
# 16   92   63  72  73   96  396  79.2
# 17   91   65  52  63   78  349  69.8
# 18   72   50  51  97  100  370  74.0
# 19   55   88  74  93   83  393  78.6
# 20   59   75  90  61   84  369  73.8
# 21   57   96  86  69   64  372  74.4
# 22   71   59  93  69   53  345  69.0
# 23   69   84  74  91  100  418  83.6
# 24   59   52  64  99   86  360  72.0
# ...

# %%
scores_df
# Out:
#      國文   英文  數學  地理   歷史      總分    平均
# 1    97   99  79  50  100   935.0  85.0
# 2    68   79  75  97   98   917.4  83.4
# 3    69   54  62  68   82   737.0  67.0
# 4    81   98  78  57   67   838.2  76.2
# 5    88   53  66  57   52   695.2  63.2
# 6    62   64  99  84   60   811.8  73.8
# 7    57   60  71  57   83   721.6  65.6
# 8    60   52  78  92   95   829.4  75.4
# 9    53   94  75  50   78   770.0  70.0
# 10   53   70  83  69   77   774.4  70.4
# 11   75   60  51  73   72   728.2  66.2
# 12   64   61  52  61   67   671.0  61.0
# 13   93   52  68  71   71   781.0  71.0
# 14   98   83  60  78   64   842.6  76.6
# 15   53   82  83  88   54   792.0  72.0
# 16   92   63  72  73   96   871.2  79.2
# 17   91   65  52  63   78   767.8  69.8
# 18   72   50  51  97  100   814.0  74.0
# 19   55   88  74  93   83   864.6  78.6
# 20   59   75  90  61   84   811.8  73.8
# 21   57   96  86  69   64   818.4  74.4
# 22   71   59  93  69   53   759.0  69.0
# ...

# %%
scores_df[['國文', '英文', '數學', '地理', '歷史']]
# Out:
#      國文   英文  數學  地理   歷史
# 1    97   99  79  50  100
# 2    68   79  75  97   98
# 3    69   54  62  68   82
# 4    81   98  78  57   67
# 5    88   53  66  57   52
# 6    62   64  99  84   60
# 7    57   60  71  57   83
# 8    60   52  78  92   95
# 9    53   94  75  50   78
# 10   53   70  83  69   77
# 11   75   60  51  73   72
# 12   64   61  52  61   67
# 13   93   52  68  71   71
# 14   98   83  60  78   64
# 15   53   82  83  88   54
# 16   92   63  72  73   96
# 17   91   65  52  63   78
# 18   72   50  51  97  100
# 19   55   88  74  93   83
# 20   59   75  90  61   84
# 21   57   96  86  69   64
# 22   71   59  93  69   53
# 23   69   84  74  91  100
# 24   59   52  64  99   86
# 25   99   57  97  50   89
# 26   53   97  99  94   93
# 27  100   70  57  69   84
# 28   90   89  54  76   93
# 29   63   57  91  62   79
# 30   69   72  88  92   74
# 31   80   81  95  62   53
# 32   68   82  79  88   70
# 33   80   67  61  90   99
# 34   91   68  76  65   96
# ...

# %%
#scores_df[['國文', '英文', '數學', '地理', '歷史']]
from pandas import Series
def get_level(s:Series):
    return'甲'

scores_df[['國文', '英文', '數學', '地理', '歷史']].apply(get_level,axis=1)
# Out:
# 1     甲
# 2     甲
# 3     甲
# 4     甲
# 5     甲
# 6     甲
# 7     甲
# 8     甲
# 9     甲
# 10    甲
# 11    甲
# 12    甲
# 13    甲
# 14    甲
# 15    甲
# 16    甲
# 17    甲
# 18    甲
# 19    甲
# 20    甲
# 21    甲
# 22    甲
# 23    甲
# 24    甲
# 25    甲
# 26    甲
# 27    甲
# 28    甲
# 29    甲
# 30    甲
# 31    甲
# 32    甲
# 33    甲
# 34    甲
# 35    甲
# 36    甲
# 37    甲
# 38    甲
# 39    甲
# 40    甲
# 41    甲
# 42    甲
# 43    甲
# 44    甲
# 45    甲
# 46    甲
# 47    甲
# 48    甲
# 49    甲
# 50    甲
# dtype: object

# %%
#scores_df[['國文', '英文', '數學', '地理', '歷史']]
from pandas import Series
def get_level(s:Series):
    print(s.min)
    return'甲'

scores_df[['國文', '英文', '數學', '地理', '歷史']].apply(get_level,axis=1)
# Out:
# <bound method Series.min of 國文     97
# 英文     99
# 數學     79
# 地理     50
# 歷史    100
# Name: 1, dtype: int64>
# <bound method Series.min of 國文    68
# 英文    79
# 數學    75
# 地理    97
# 歷史    98
# Name: 2, dtype: int64>
# <bound method Series.min of 國文    69
# 英文    54
# 數學    62
# 地理    68
# 歷史    82
# Name: 3, dtype: int64>
# <bound method Series.min of 國文    81
# 英文    98
# 數學    78
# 地理    57
# 歷史    67
# Name: 4, dtype: int64>
# <bound method Series.min of 國文    88
# 英文    53
# 數學    66
# 地理    57
# 歷史    52
# Name: 5, dtype: int64>
# <bound method Series.min of 國文    62
# 英文    64
# 數學    99
# 地理    84
# 歷史    60
# Name: 6, dtype: int64>
# <bound method Series.min of 國文    57
# 英文    60
# 數學    71
# 地理    57
# 歷史    83
# Name: 7, dtype: int64>
# <bound method Series.min of 國文    60
# 英文    52
# 數學    78
# 地理    92
# 歷史    95
# Name: 8, dtype: int64>
# <bound method Series.min of 國文    53
# 英文    94
# 數學    75
# 地理    50
# 歷史    78
# Name: 9, dtype: int64>
# ...

# %%
#scores_df[['國文', '英文', '數學', '地理', '歷史']]
#dataFrame應用自訂的function
from pandas import Series

def get_level(s:Series):
    average = s.mean()
    if average < 60:
        return '不及格'
    elif average < 80:
        return '甲'
    else:
        return '優'


scores_df[['國文', '英文', '數學', '地理', '歷史']].apply(get_level,axis=1)
# Out:
# 1     優
# 2     優
# 3     甲
# 4     甲
# 5     甲
# 6     甲
# 7     甲
# 8     甲
# 9     甲
# 10    甲
# 11    甲
# 12    甲
# 13    甲
# 14    甲
# 15    甲
# 16    甲
# 17    甲
# 18    甲
# 19    甲
# 20    甲
# 21    甲
# 22    甲
# 23    優
# 24    甲
# 25    甲
# 26    優
# 27    甲
# 28    優
# 29    甲
# 30    甲
# 31    甲
# 32    甲
# 33    甲
# 34    甲
# 35    甲
# 36    甲
# 37    甲
# 38    甲
# 39    優
# 40    甲
# 41    甲
# 42    甲
# 43    甲
# 44    甲
# 45    甲
# 46    甲
# 47    甲
# 48    優
# 49    甲
# 50    優
# dtype: object

# %%
#scores_df[['國文', '英文', '數學', '地理', '歷史']]
#dataFrame應用自訂的function
from pandas import Series

def get_level(s:Series):
    average = s.mean()
    if average < 60:
        return '不及格'
    elif average < 80:
        return '甲'
    else:
        return '優'


scores_df['等級'] = scores_df[['國文', '英文', '數學', '地理', '歷史']].apply(get_level,axis=1)

# %%
scores_df
# Out:
#      國文   英文  數學  地理   歷史      總分    平均 等級
# 1    97   99  79  50  100   935.0  85.0  優
# 2    68   79  75  97   98   917.4  83.4  優
# 3    69   54  62  68   82   737.0  67.0  甲
# 4    81   98  78  57   67   838.2  76.2  甲
# 5    88   53  66  57   52   695.2  63.2  甲
# 6    62   64  99  84   60   811.8  73.8  甲
# 7    57   60  71  57   83   721.6  65.6  甲
# 8    60   52  78  92   95   829.4  75.4  甲
# 9    53   94  75  50   78   770.0  70.0  甲
# 10   53   70  83  69   77   774.4  70.4  甲
# 11   75   60  51  73   72   728.2  66.2  甲
# 12   64   61  52  61   67   671.0  61.0  甲
# 13   93   52  68  71   71   781.0  71.0  甲
# 14   98   83  60  78   64   842.6  76.6  甲
# 15   53   82  83  88   54   792.0  72.0  甲
# 16   92   63  72  73   96   871.2  79.2  甲
# 17   91   65  52  63   78   767.8  69.8  甲
# 18   72   50  51  97  100   814.0  74.0  甲
# 19   55   88  74  93   83   864.6  78.6  甲
# 20   59   75  90  61   84   811.8  73.8  甲
# 21   57   96  86  69   64   818.4  74.4  甲
# ...
